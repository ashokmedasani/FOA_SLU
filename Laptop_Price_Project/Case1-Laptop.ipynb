# %% [markdown]
# #Week2: Laptop Price Project
#
#
#
# ---
#
# **Project Name**: Laptop Prices
#
# Team Details:
#
#  1. Ashok Medasani
#  2. Bindu Veeravalli
#  3. Sridhar Reddy Somireddy

# %% [markdown]
# **Introduction**
#
# In this project, we will load and analyze laptop prices data

# %% [markdown]
# Step 1: Load data

# %%
#Mount Google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Change the directory to where the project folder is located

import os
os.chdir("/content/drive/MyDrive/FALL2-AA5000/Week2/P1_LaptopPrices")

# %%
#Load the data

import pandas as pd

df = pd.read_csv("data/laptop_pricing_dataset_mod2-1.csv")

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Manufacturer', 'Category', 'GPU', 'OS',
#        'CPU_core', 'Screen_Size_inch', 'CPU_frequency', 'RAM_GB',
#        'Storage_GB_SSD', 'Weight_pounds', 'Price', 'Price-binned',
#        'Screen-Full_HD', 'Screen-IPS_panel'],
#       dtype='object')

# %%
#Drop the unnecessary columns and take that as new df

df_clean = df.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0'])

# %%
print(df)
# Out:
#      Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0               0           0         Acer         4    2   1         5
# 1               1           1         Dell         3    1   1         3
# 2               2           2         Dell         3    1   1         7
# 3               3           3         Dell         4    2   1         5
# 4               4           4           HP         4    2   1         7
# ..            ...         ...          ...       ...  ...  ..       ...
# 233           233         233       Lenovo         4    2   1         7
# 234           234         234      Toshiba         3    2   1         5
# 235           235         235       Lenovo         4    2   1         5
# 236           236         236       Lenovo         3    3   1         5
# 237           237         237      Toshiba         3    2   1         5
#
#      Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# ...

# %% [markdown]
# Univariate Analysis
#
# If Numerical -> Make Histograms
#
# If Categorical -> Bar Graphs

# %%
#Get the count of each value in the Manufacturer column

manufacturer_counts = df_clean['Manufacturer'].value_counts()

# Convert teh counts to a df to work easily

manufacturer_counts_df = pd.DataFrame(manufacturer_counts).reset_index()
manufacturer_counts_df.columns = ['Manufacturer','Count']

print(manufacturer_counts_df)
# Out:
#    Manufacturer  Count
# 0          Dell     71
# 1        Lenovo     52
# 2            HP     49
# 3          Acer     19
# 4          Asus     18
# 5       Toshiba     17
# 6       Samsung      5
# 7           MSI      4
# 8        Huawei      1
# 9         Razer      1
# 10       Xiaomi      1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Sort the Dataframe by count in descending order

manufacturer_counts_df = manufacturer_counts_df.sort_values(by= "Count", ascending= False)

#Set the style of Seaborn
sns.set_style("whitegrid")

#Set the palette
palette = sns.color_palette('pastel')

# Create the bar graph
plt.figure(figsize= (10,6))
sns.barplot(data = manufacturer_counts_df, x= 'Manufacturer', y = 'Count', palette = palette)
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.title('Count of laptops by Manufacturer')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Histogram**

# %%
sns.histplot(df_clean['Price'], kde = True, color = 'skyblue')
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show();

# %%
sns.boxplot(df_clean['Price'],color='salmon')
plt.title('Boxplot of Price')
plt.show()

# %%
print(df_clean['Price'].describe())
# Out:
# count    238.00
# mean    1462.34
# std      574.61
# min      527.00
# 25%     1066.50
# 50%     1333.00
# 75%     1777.00
# max     3810.00
# Name: Price, dtype: float64

# %% [markdown]
# Bivarient Analysis

# %% [markdown]
# Numerical and Numerical
#
# Scatterplot

# %%
sns.scatterplot(x = 'Weight_pounds', y = 'Price', data = df_clean)
plt.title('Scatterplot of Weight vs Price')
plt.xlabel('Weight in Pounds')
plt.ylabel('Price')
plt.show()

# %%
sns.regplot(x = 'RAM_GB', y = 'Price', data = df_clean, ci = False)
plt.title('Regplot of RAM vs Price')
plt.xlabel('RAM in GB')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Categorical and Numerical
#
# Boxplots

# %%
print(df_clean[['Manufacturer','Price']])
# Out:
#     Manufacturer  Price
# 0           Acer    978
# 1           Dell    634
# 2           Dell    946
# 3           Dell   1244
# 4             HP    837
# ..           ...    ...
# 233       Lenovo   1891
# 234      Toshiba   1950
# 235       Lenovo   2236
# 236       Lenovo    883
# 237      Toshiba   1499
#
# [238 rows x 2 columns]

# %%
plt.figure(figsize = (10,6))
sns.boxplot(x ='Manufacturer', y ='Price', data = df_clean, palette = palette)
plt.title('Boxplot of Price by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
df_clean.columns
# Out:
# Index(['Manufacturer', 'Category', 'GPU', 'OS', 'CPU_core', 'Screen_Size_inch',
#        'CPU_frequency', 'RAM_GB', 'Storage_GB_SSD', 'Weight_pounds', 'Price',
#        'Price-binned', 'Screen-Full_HD', 'Screen-IPS_panel'],
#       dtype='object')

# %% [markdown]
# **Convert to HTML**

# %%
from nbconvert import HTMLExporter
import nbformat

# Load the notebook
notebook_path = "/content/drive/MyDrive/FALL2-AA5000/Week2/P1_LaptopPrices/codes/Case1-Laptop.ipynb"
output_html_path = "/content/drive/MyDrive/FALL2-AA5000/Week2/P1_LaptopPrices/html/ashok_bindu_sridhar.html"

with open(notebook_path) as f:
  notebook_content = nbformat.read(f, as_version=4)

# Convert to HTMl
html_exporter = HTMLExporter()
(body, resources) = html_exporter.from_notebook_node(notebook_content)

# save to HTML file
with open(output_html_path, 'w') as f:
  f.write(body)

# %% [markdown]
# InClass Assignment
#
# **Assignment:**
#
# Need to repeat all steps again with different Categorical annd Numerical value

# %% [markdown]
# **Categorical and Numberical separation** Image

# %%
from IPython.display import Image

# Display the image with specified width and height
Image(filename="/content/drive/MyDrive/FALL2-AA5000/Week2/P1_LaptopPrices/data/Assignment Week 1.jpeg",width=700, height=700)

# %%
df_clean.columns
# Out:
# Index(['Manufacturer', 'Category', 'GPU', 'OS', 'CPU_core', 'Screen_Size_inch',
#        'CPU_frequency', 'RAM_GB', 'Storage_GB_SSD', 'Weight_pounds', 'Price',
#        'Price-binned', 'Screen-Full_HD', 'Screen-IPS_panel'],
#       dtype='object')

# %% [markdown]
# Univariate Analysis
#
# If Numerical -> Make Histograms
#
# If Categorical -> Bar Graphs
#
# Bivarient Analysis
#
# Numerical and Numerical
#
# Scatterplot
#
# Categorical and Numerical
#
# Boxplots

# %%
#Get the count of each value in the Manufacturer column

price_binned_counts = df_clean['Price-binned'].value_counts()

# Convert teh counts to a df to work easily

price_binned_counts_df = pd.DataFrame(price_binned_counts).reset_index()
price_binned_counts_df.columns = ['Price-binned','Count']

print(price_binned_counts_df)
# Out:
#   Price-binned  Count
# 0          Low    160
# 1       Medium     72
# 2         High      6

# %%
# Sort the Dataframe by count in descending order

price_binned_counts_df = price_binned_counts_df.sort_values(by= "Count", ascending= False)
# print(price_binned_counts_df)
#Set the style of Seaborn
# sns.set_style("whitegrid")

#Set the palette
# palette = sns.color_palette('pastel')

# Create the bar graph
plt.figure(figsize= (6,6))
sns.barplot(data = price_binned_counts_df, x = 'Price-binned', y = 'Count', palette = palette)
plt.xlabel('Price Binned')
plt.ylabel('Count')
plt.title('Count of laptops by Price Binned')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Histogram

# %%
sns.histplot(df_clean['CPU_frequency'], kde = True, color = 'skyblue')
plt.title('Histogram of CPU Frequency')
plt.xlabel('CPU Frequency (GHz)')
plt.ylabel('Frequency Count')
plt.show()

# %% [markdown]
# Above Histogram is **Right Skewed **

# %%
sns.boxplot(df_clean['CPU_frequency'], color = 'skyblue')
plt.title('Boxplot of CPU Frequency')
plt.ylabel('CPU Frequency in GHz')
plt.show()

# %% [markdown]
# BiVarient Variable
#
# Numerical vs Numerical

# %%
sns.scatterplot(x = 'RAM_GB', y = 'CPU_frequency', data = df_clean)
plt.title('Scatterplot of CPU Frequency vs RAM')
plt.xlabel('RAM in GB')
plt.ylabel('CPU Frequency(GHz)')
plt.show()

# %%
sns.regplot(x = 'GPU', y = 'CPU_frequency', data = df_clean)
plt.title('Scatterplot of CPU Frequency vs GPU')
plt.xlabel('GPU')
plt.ylabel('CPU Frequency(GHz)')
plt.show()

# %% [markdown]
# **Categorical and Numerical**
#
# BoxPlots

# %%
print(df_clean[['Price-binned','CPU_frequency']])
# Out:
#     Price-binned  CPU_frequency
# 0            Low           0.55
# 1            Low           0.69
# 2            Low           0.93
# 3            Low           0.55
# 4            Low           0.62
# ..           ...            ...
# 233       Medium           0.90
# 234       Medium           0.83
# 235       Medium           0.90
# 236          Low           0.86
# 237          Low           0.79
#
# [238 rows x 2 columns]

# %%
plt.figure(figsize = (10,6))
sns.boxplot(x ='Price-binned', y ='CPU_frequency', data = df_clean, palette = palette)
plt.title('Boxplot of CPU Frequency wrt Price Binned')
plt.xlabel('Binned Price')
plt.ylabel('CPU Frequency(GHz)')
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2], [Text(0, 0, 'Low'), Text(1, 0, 'Medium'), Text(2, 0, 'High')])
